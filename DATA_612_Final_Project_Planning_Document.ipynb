# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaroy280/DATA612/blob/main/DATA_612_Final_Project_Planning_Document.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Final Project Planning Document**
#
# Puja Roy
#
# Summer 2026

# %% [markdown]
# ## **Planning**

# %% [markdown]
# ## **Title of Proposed Final Project: Hybrid Book Recommendation System**

# %% [markdown]
# For this final project, I plan to develop a hybrid book recommendation system using the Book Recommendation Dataset from Kaggle: https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset
#
# The recommendation system will combine collaborative filtering and content-based filtering to improve the quality of recommendations being provided to avid book worms. The system will be implemented using Python and Spark.

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# The purpose of this project is to analyze whether combining collaborative filtering and content-based filtering can potentially improve recommendation quality compared to traditional recommender system methods that depend on user-item interactions to identify preferences in user preferences.

# %% [markdown]
# ## **Dataset**

# %% [markdown]
# The Book Recommendation Dataset from Kaggle will be utilized to build the recommender system.
#
# The dataset contains:
#
# - Approximately 278,858 users
#
# - Approximately 271,379 books
#
# - Approximately 1,149,780 ratings
#
# The dataset includes three main files:
#
# 1) **Ratings Dataset**
#
# Contains user-book interactions:
#
# - User ID
# - ISBN
# - Rating
#
# This dataset will be used for collaborative filtering.
#
#
# 2) **Books Dataset**
#
# Contains book information:
#
# - ISBN
# - Book title
# - Author
# - Publisher
# - Year of publication
# - Cover image URL
#
# This dataset will be used for content-based recommendation.
#
# 3) **Users Dataset**
#
# Contains user information:
#
# - User ID
# - Age
# - Location
#
# This information might be used for exploratory analysis.

# %% [markdown]
# ## **Project Objectives**

# %% [markdown]
# The goals of this project are:
#
# - Process a large-scale recommendation dataset using Apache Spark.
# - Build a collaborative filtering recommendation model.
# - Build a content-based recommendation model.
# - Develop a hybrid recommendation approach.
# - Compare recommendation performance across different models.
# - Evaluate the effectiveness of combining user behavior and item characteristics.

# %% [markdown]
# ## **Model Evaluation**

# %% [markdown]
# The recommendation models will be evaluated using both rating prediction metrics and Top-N recommendation metrics:
#
# - **Root Mean Squared Error (RMSE)**
#
#   Measure the difference between predicted and actual ratings.
#
#   Recommendation quality will primarily be evaluated using Top-N ranking metrics.
#
#   Will be leveraged to evaluate the accuracy of the collaborative filtering model.
#
#   While RMSE will measure prediction accuracy, the primary model evaluation will focus on the quality and ranking of the recommended books.
#
# - **Precision@K**
#
#   Measures the top-K how many recommended books are relevant to the user.
#
# - **Recall@K**
#
#   Measures how many relevant books are successfully recommended within the top-K recommendations.
#
# - **Mean Average Precision (MAP@K)**
#
#   Measures the overall ranking quality based on the position of relevant books across all users.
#
# - **Normalized Discounted Cumulative Gain (NDCG@K)**
#
#   Measures how well the recommender ranks relevant books near the top of the recommendation list.
#
#   The collaborative filtering, content-based filtering, and hybrid recommendation models will be evaluated using the same train-test split and compared based on RMSE, Precision@K, Recall@K, MAP@K, and NDCG@K. If the hybrid recommender consistently produces the highest Top-K recommendation quality, especially with Precision@K, Recall@K, MAP@K, and NDCG@K, that will indicate that the hybrid recommender is considered the best performing model.
