# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaroy280/DATA612/blob/main/DATA612_Research_Discussion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Research Discussion 2**
# Puja Roy
#
# Summer 2026

# %% [markdown]
# For this discussion item, please watch the following talk and summarize what you found to be the most important or interesting points. The first half will cover some of the mathematical techniques covered in this unit's reading and the second half some of the data management challenges in an industrial-scale recommendation system.
#
# Music Recommendations at Scale with Spark - Christopher Johnson (Spotify)
# Duration: 26:29
# User: n/a - Added: 7/17/14
# YouTube URL: http://www.youtube.com/watch?v=3LBgiFch4_g

# %% [markdown]
# One of the points from Christopher Johnsons presentation *Music Recommendations at Scale with Spark* was that Spotify does not rely on one method to recommend music.
#
# Spotify uses music recommendations from sources such as
#
# * what other people are listening to
#
# * information about the music
#
# * how the music sounds
#
# * what people say about the music
#
# * what words are used to describe the music
#
# to make music recommendations.
#
# The way Spotify analyzes what people are listening to is really cool. They look at what people do. For example:
#
# * what they listen to
#
# * what they skip
#
# * what they listen to again
#
# * what they add to playlists.
#
# By looking at this information for millions of people Spotify finds relationships between people and music.
#
# Spotify also uses information about the music. This includes details like
#
# * who the artistsre
#
# * what album the music is from
#
# * what kind of music it is
#
# * when it was released.
#
# This information helps Spotify make recommendations for music that does not have listening data yet.
#
# I also thought it was really cool how Spotify analyzes the music itself. They look at things like
#
# * how fast or slow the music is
#
# * what the rhythm is like
#
# * how energetic the music is
#
# * how loud it is.
#
# This helps Spotify recommend music that sounds similar.
#
# The presentation also talked about how Spotify uses tags and what people say about the music. Tags are like words that describe the music, such as
#
# * what mood it's in
#
# * what style it is.
#
# Spotify can also look at what people're saying about music online.
#
# The second half of the presentation was about the challenges of making recommendations for millions of people. With many people listening to music it is hard to process all the data.
#
# Christopher Johnson explained how Spotify uses Apache Spark to make things faster.
#
# Apache Spark is good at handling datasets.
#
# What I took away from the presentation was that Spotify combines
#
# * what people are listening to
#
# * information, about the music
#
# * how the music sounds
#
# * tags
#
# * what people say about the music
#
# to make recommendations. This helps Spotify make music recommendations better.
