# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaroy280/DATA612/blob/main/DATA_612_Project_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project 6: Azure Deployment**
# Puja Roy
#
# Summer 2026

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# The purpose of this project was to work on a hands on Azure project by deploying a previous recommender system or cloud solution to Microsoft Azure. For this project, I select Project 4: Accuracy & Beyond project in which I utilized the Anime Recommendations Database Kaggle dataset from Kaggle.

# %% [markdown]
# ## **Persistent Storage**

# %% [markdown]
# I used a long-term storage solution file/blob storage using Azure Blob Storage. I had to create a free MS Azure account to access the Azure Portal.

# %% [markdown]
# ![MSAzureBlobStorage_AnimeRecommendations.png](data:image/png;base64,...)

# %% [markdown]
# Once I successfully created the storage account, I had limited options in compute due to restrictions from the Azure Subscription, I ran the code locally in Google Colab and connected the data in cloud storage by pasting the connection string key.
#
# `azure-storage-blob` library was installed and the data from the Azure Blob Storage was loaded into the `anime` and `ratings` DataFrames. The connection to Azure Blob Storage was successfully established, and the ratings and anime DataFrames were loaded.

# %%
import sys
# !{sys.executable} -m pip install azure-storage-blob

from azure.storage.blob import BlobServiceClient
from io import BytesIO
import pandas as pd

connection_string = "DefaultEndpointsProtocol=https;AccountName=animecloudstorage;AccountKey=dC4fUJLGYIXFyz8kjnQ1k7fBoO2ltR8M1ZBwfSco/NYIj6TrGwPWRQEdvDG6NnsYD17HAWd8449X+AStdxp6MQ==;EndpointSuffix=core.windows.net"

container_name = "anime-data"

blob_service = BlobServiceClient.from_connection_string(connection_string)

def load_blob(filename):
    blob_client = blob_service.get_blob_client(
        container=container_name,
        blob=filename
    )

    data = blob_client.download_blob()

    return pd.read_csv(BytesIO(data.readall()))

ratings = load_blob("rating.csv")
anime = load_blob("anime.csv")

# %%
display(ratings.head())
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %% [markdown]
# ##**Compute Resource**

# %% [markdown]
# I used a virtual machine via Azure Virtual Machine as the compute resource service.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Network Security**

# %% [markdown]
# From there on, I configured Network Security Group (NSG) in the Microsoft Azure Portal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
