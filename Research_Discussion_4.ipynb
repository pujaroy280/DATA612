# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaroy280/DATA612/blob/main/Research_Discussion_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Research Discussion 4**
#
# Puja Roy
#
# Summer 2026

# %% [markdown]
# Mitigating the Harm of Recommender Systems
#
# Read one or more of the articles below and consider how to counter the radicalizing effects of recommender systems or ways to prevent algorithmic discrimination.
#
# Renee Diresta, Wired.com (2018): Up Next: A Better Recommendation System
#
# Zeynep Tufekci, The New York Times (2018): YouTube, the Great Radicalizer
#
# Sanjay Krishnan, Jay Patel, Michael J. Franklin, Ken Goldberg (n/a): Social Influence Bias in Recommender Systems: A Methodology for Learning, Analyzing, and Mitigating Bias in Ratings

# %% [markdown]
# After reading the articles above, below is my response on how to encounter alternate methods to present recommender systems in a way that is not harmful to consumers:
#
# Recommender systems can be extremely harmful for people. They are designed to keep people engaged like making them click or watch videos by displaying a mix of information similar to an original information. This can cause problems. For example, recommender systems might show people content that keeps them interested which is not always beneficial for people.
#
# People might also only view things over and over which means they miss out on viewpoints that're not as well known as other viewpoints.
#
# To improve recommender systems the people who design recommender systems can change their goals. They can try to make sure everyone see a bit of everything so people are happy for a time not just for a short time.
#
# For instance, the people who design recommender systems can make sure people do not just see things one after another. Instead recommender systems can show people lots of things. The people who make recommender systems can also make sure that just because something is popular it does not mean everyone has to see it.
#
# It is also an idea to let people know why they are seeing things on recommender systems. People can choose what they want to see on recommender systems. The people who make these recommender systems can explain why they are showing things on recommender systems. They can let people say what they like and what they do not like about recommender systems.
#
# This helps make recommender systems for people. It makes sure people see a variety of things when they are online using recommender systems. That is a thing, for both recommender systems and people who use recommender systems.
